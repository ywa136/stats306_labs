# %% [markdown]
# # Lab 2: More ggplot and dplyr

# %%
library(tidyverse)
# Out:
# ── Attaching packages ─────────────────────────────────────── tidyverse 1.2.1 ──
#
# ✔ ggplot2 3.1.0     ✔ purrr   0.3.0
# ✔ tibble  2.1.3     ✔ dplyr   0.8.1
# ✔ tidyr   0.8.2     ✔ stringr 1.3.1
# ✔ readr   1.1.1     ✔ forcats 0.3.0
#
# Warning message:
# “package ‘tibble’ was built under R version 3.5.2”
# Warning message:
# “package ‘dplyr’ was built under R version 3.5.2”
# ── Conflicts ────────────────────────────────────────── tidyverse_conflicts() ──
# ✖ dplyr::filter() masks stats::filter()
# ✖ dplyr::lag()    masks stats::lag()

# %%
rand_idx = runif(1000, min=1, max=dim(diamonds)[1])
dm = diamonds[rand_idx, ]
names(dm)
dim(dm)
# Out:
#  [1] "carat"   "cut"     "color"   "clarity" "depth"   "table"   "price"
#  [8] "x"       "y"       "z"
# [1] 1000   10

# %% [markdown]
# # ggplot

# %% [markdown]
# ## Geometric objects
# So far we have plotted the points in a fundamental manner. We might be interested in the linear trends of the data that we have.

# %%
p2 = ggplot(dm,aes(x=carat,y=price)) +
    geom_point() +
    geom_smooth(method = 'lm',se=T)
print(p2)
# Out:
# plot without title

# %% [markdown]
# ### Exercise:
# 1. Try to produce the same plot but using method = 'loess'.
# 2. What does the se argument do in the geom_smooth function?

# %%
p3 = ggplot() + 
    geom_point() + 
    geom_smooth()

# %% [markdown]
# ### Exercise
# 1. What if you want to see the trend for each category of clarity?
# 2. Run this code in your head and predict what the output will look like. Then, run the code in R and check your predicions.

# %%
p4 = ggplot() + 
    geom_point() + 
    geom_smooth()

# %% [markdown]
# ## Statistical transformations
# Many graphs, like scatterplots, plot the raw values of your dataset. Other graphs, like bar charts, calculate new values to plot.
#
# You can learn which stat a geom uses by inspecting the default value for the 'stat' argument. For example, ?geom_bar shows that the default value for stat is 'count', which means that geom_bar() uses stat_count().
#
# stat_count() is documented on the same page as geom_bar(), and if you scroll down you can find a section called "computed variables." That describes how it computes two new variables: count and prop.
#
# Let's use the following case where we override the default stat and instead want to use a value within the dataset of the y-axis (instead of a count).

# %% [markdown]
# ## Position adjustments

# %%
ggplot(data = diamonds) + 
  geom_bar(mapping = aes(x = cut, colour = clarity))
ggplot(data = diamonds) + 
  geom_bar(mapping = aes(x = cut, fill = clarity))
# Out:
# plot without title
# plot without title

# %% [markdown]
# Remmeber that we can "color by" a different variable - in this case, clarity. By default, it stacks the bars for each clarity level. This is done using the positional adjustment specified by the position argument of geom_bar. If you don't want a stacked bar chart, you can use one of three other options: "identity", "dodge", or "fill".

# %% [markdown]
# *position = "identity"*
# This will place each object exactly where it falls in the context of the graph. This is not very useful for bars, because it overlaps them. To see that overlapping we either need to make the bars slightly transparent by setting alpha to a small value, or completely transparent by fill=NA

# %%
ggplot(diamonds) + 
  geom_bar(mapping = aes(x = cut, fill = clarity), position='identity')
# Out:
# plot without title

# %%
ggplot(diamonds) + 
  geom_bar(aes(x = cut, fill = clarity), position = 'identity')
# Out:
# plot without title

# %% [markdown]
# *position 'fill'*
# This works like stacking, but makes each set of stacked bars the same height. This makes it easier to compare proportions across groups.

# %%
ggplot(data = dm) + 
  geom_bar(mapping = aes(x = cut, fill = clarity), position = "fill")
# Out:
# plot without title

# %% [markdown]
# *position = 'dodge'*
#
# This places overlapping objects directly beside one another, which makes it easier to compare individual values.

# %%
ggplot(data = dm) + 
  geom_bar(mapping = aes(x = cut, fill = clarity), position = "dodge")
# Out:
# plot without title

# %% [markdown]
# # dplyr for data manipulation

# %%
dim(dm)
head(dm)
# Out:
# [1] 1000   10
#   carat cut       color clarity depth table price x    y    z
# 1 0.32  Ideal     D     SI1     62.6  55     756  4.39 4.36 2.74
# 2 0.40  Ideal     E     VVS1    62.6  56    1397  4.73 4.70 2.95
# 3 0.70  Very Good F     VS1     62.2  58    2889  5.64 5.75 3.54
# 4 0.32  Premium   G     VS1     62.5  60     828  4.35 4.29 2.70
# 5 1.00  Premium   F     VS2     62.8  59    6328  6.35 6.32 3.98
# 6 0.33  Very Good G     VVS2    59.7  59     806  4.48 4.53 2.69

# %% [markdown]
# There are five functions in dplyr: filter, arrange, select, mutate and summarise. All of them have the following properties:
# 1. The first argument is a data frame.
# 2. The subsequent arguments describe what to do with the data frame, using the variable names( without quotes).
# 3. The result is a new data frame.

# %% [markdown]
# ## Filter
# Used if you want to view or store a new dataset containing a subset of the full dataset.

# %%
filter(dm, cut == 'Fair', color == 'J')
# Out:
#   carat cut  color clarity depth table price x    y   z
# 1 0.74  Fair J     VS1     58.8  68    1982  5.91 5.8 3.44

# %% [markdown]
# Usually you want to store the newly subsetted data in memory.

# %%
worst_diamonds = filter(dm, cut == 'Fair', color == 'J')

# %% [markdown]
# Make sure to use '==' instead of '='. The former is to test equality while the latter is for assignments.

# %%
4 == 6
test = 6
test
test == 5
# Out:
# [1] FALSE
# [1] 6
# [1] FALSE

# %%
a = filter(dm, color == 'D' | color == 'J') 
# filtering for rows that satisfy one or both of the conditions

b = filter(dm, color == 'D' & color == 'J') 
# filtering for rows that satisfy both conditions

c = filter(dm, color == 'D') 
# filtering for rows that satisfy exactly one condition

best_cuts = filter(dm, cut %in% c('Ideal','Premium')) 
# filtering using membership condition

not_worst_cuts = filter(dm, cut > 'Fair') 
# can do this because cut is an ordinal variable

# %%
not_worst_cuts[1:20,]
# Out:
#    carat cut       color clarity depth table price x    y    z
# 1  0.32  Ideal     D     SI1     62.6  55      756 4.39 4.36 2.74
# 2  0.40  Ideal     E     VVS1    62.6  56     1397 4.73 4.70 2.95
# 3  0.70  Very Good F     VS1     62.2  58     2889 5.64 5.75 3.54
# 4  0.32  Premium   G     VS1     62.5  60      828 4.35 4.29 2.70
# 5  1.00  Premium   F     VS2     62.8  59     6328 6.35 6.32 3.98
# 6  0.33  Very Good G     VVS2    59.7  59      806 4.48 4.53 2.69
# 7  1.04  Premium   D     SI2     61.0  59     4724 6.51 6.54 3.98
# 8  1.39  Ideal     E     VS2     60.8  57    11726 7.24 7.21 4.39
# 9  0.31  Ideal     D     VS1     61.6  54      696 4.33 4.37 2.68
# 10 1.61  Very Good E     SI1     62.3  57    13047 7.43 7.47 4.64
# 11 2.19  Premium   E     SI2     62.4  61    18232 8.31 8.23 5.16
# 12 0.54  Ideal     D     VVS2    61.4  52     2897 5.30 5.34 3.26
# 13 0.50  Ideal     E     SI1     62.2  57     1415 5.11 5.05 3.16
# 14 0.93  Good      D     SI2     61.4  63     4165 6.22 6.26 3.83
# 15 0.77  Premium   J     SI1     61.8  59     2010 5.86 5.82 3.61
# 16 1.02  Ideal     D     VS1     60.8  55     8818 6.55 6.50 3.97
# 17 1.27  Premium   G     VVS2    61.0  58    10203 6.96 7.01 4.26
# 18 0.31  Very Good D     SI2     62.9  54      462 4.30 4.35 2.72
# 19 1.13  Premium   I     VS1     61.7  54     5316 6.74 6.71 4.15
# 20 1.00  Ideal     J     VS1     62.3  56     4144 6.43 6.38 3.99

# %% [markdown]
# In R, if you want to find if a variable's value is missing, use the is.na() function. In particular, do not check for equality with NA:

# %%
x = 4
x == NA
is.na(x)
# Out:
# [1] NA
# [1] FALSE

# %% [markdown]
# Similarly, never put an equality condition with NA in your dplyr filter() statements

# %%
# create a dataframe
df = tibble(x = c(1, NA, 3))
print(df)
# Out:
# # A tibble: 3 x 1
#       x
#   <dbl>
# 1     1
# 2    NA
# 3     3

# %%
filter(df, x>1)
# Out:
#   x
# 1 3

# %%
filter(df, is.na(x) | x > 1)
# Out:
#   x
# 1 NA
# 2  3

# %% [markdown]
# ### Exercise
# 1. Write code using filter that will allow you to output diamonds with colors D or E and cuts Good or Very Good
# 2. Write code using filter that wil allow you to output diamonds with even-numbered prices

# %% [markdown]
# ## Arrange
# Useful for ordering rows instead of filtering for a subset of them

# %%
arrange(dm, cut, color)[1:20,] 
# can be done since clarity is an ordinal variable
# Out:
#    carat cut  color clarity depth table price x    y    z
# 1  0.50  Fair D     SI1     64.6  61     1238 5.05 4.95 3.23
# 2  0.70  Fair D     SI1     66.0  56     2093 5.45 5.52 3.62
# 3  1.50  Fair D     I1      64.7  62     5460 7.19 7.04 4.60
# 4  0.50  Fair E     VS2     79.0  73     2579 5.21 5.18 4.09
# 5  0.50  Fair E     SI1     65.3  58     1134 4.99 4.91 3.23
# 6  0.50  Fair E     SI2     58.0  67      851 5.26 5.17 3.02
# 7  0.70  Fair E     VS2     65.6  61     2352 5.62 5.47 3.64
# 8  0.98  Fair F     SI1     61.8  66     3622 6.38 6.27 3.91
# 9  0.75  Fair F     VS1     55.8  70     2859 6.09 5.98 3.37
# 10 0.33  Fair F     VVS2    65.7  54      693 4.37 4.30 2.85
# 11 0.50  Fair F     SI1     66.5  59      994 5.01 4.91 3.30
# 12 1.13  Fair F     VS1     64.5  55     7335 6.62 6.56 4.25
# 13 2.10  Fair G     I1      64.6  58     6597 8.05 8.01 5.19
# 14 1.01  Fair G     SI2     65.1  58     3461 6.29 6.21 4.07
# 15 0.50  Fair G     VS1     67.6  56     1257 5.02 4.89 3.35
# 16 0.84  Fair G     VS1     55.6  64     2724 6.42 6.32 3.54
# 17 2.00  Fair G     SI1     65.5  58    11935 7.82 7.73 5.09
# 18 1.01  Fair G     VS2     65.1  56     5950 6.20 6.15 4.02
# 19 1.70  Fair G     VS2     64.5  58    14860 7.51 7.43 4.82
# 20 1.52  Fair H     I1      64.9  58     3504 7.18 7.13 4.65

# %%
# arranging in the descending order of carat and then cut
arrange()[1:20,]
# Out:
# Error in arrange_(.data, .dots = compat_as_lazy_dots(...)): argument ".data" is missing, with no default
# Traceback:
#
# 1. arrange()
# 2. arrange.default()
# 3. arrange_(.data, .dots = compat_as_lazy_dots(...))

# %% [markdown]
# Missing values are always sorted at the end:

# %%
df = tibble(x = c(5, NA, 2))
arrange(df, x)
# Out:
#   x
# 1  2
# 2  5
# 3 NA

# %%
arrange(df, desc(x))
# Out:
#   x
# 1  5
# 2  2
# 3 NA

# %% [markdown]
# ### Exercise
# 1. Use arrange to sort the dm dataset by describing order of the product of the x, y, and z variables. Output the first 20 rows of the new dataset.
#
# ## Select
# This is used to reduce the number of columns that we're dealing with. Useful for things like genetic data

# %%
names(dm)
# Out:
#  [1] "carat"   "cut"     "color"   "clarity" "depth"   "table"   "price"
#  [8] "x"       "y"       "z"

# %%
select(dm, carat, price)[1:20,]
# Out:
#    carat price
# 1  0.33   666
# 2  2.10  6597
# 3  0.54  2616
# 4  1.26  6657
# 5  0.30   426
# 6  0.32   910
# 7  1.02  5198
# 8  0.24   552
# 9  0.51  1656
# 10 1.02  7277
# 11 0.83  2241
# 12 0.79  3861
# 13 0.41   705
# 14 0.26   769
# 15 0.96  3187
# 16 0.30   552
# 17 0.54  2210
# 18 0.50  1286
# 19 0.53  2290
# 20 1.35  6754

# %%
select(dm, carat:price)[1:20,]
# Out:
#    carat cut       color clarity depth table price
# 1  0.33  Ideal     F     VS2     62.1  55     666
# 2  2.10  Fair      G     I1      64.6  58    6597
# 3  0.54  Ideal     E     VVS2    62.2  54    2616
# 4  1.26  Premium   F     SI2     61.3  58    6657
# 5  0.30  Ideal     D     SI2     62.0  56     426
# 6  0.32  Ideal     D     VVS1    61.8  56     910
# 7  1.02  Premium   D     SI2     59.7  60    5198
# 8  0.24  Very Good E     VVS2    60.0  57     552
# 9  0.51  Ideal     E     VS2     62.2  57    1656
# 10 1.02  Very Good E     SI1     63.7  55    7277
# 11 0.83  Premium   J     SI2     59.1  60    2241
# 12 0.79  Ideal     E     VS2     62.2  55    3861
# 13 0.41  Very Good E     SI1     59.3  61     705
# 14 0.26  Ideal     F     VVS2    61.6  57     769
# 15 0.96  Premium   J     SI1     62.9  59    3187
# 16 0.30  Very Good I     VVS1    62.8  59     552
# 17 0.54  Ideal     H     IF      60.3  55    2210
# 18 0.50  Ideal     F     SI1     59.9  57    1286
# 19 0.53  Ideal     F     VS2     61.6  56    2290
# 20 1.35  Ideal     J     VS2     61.8  54    6754

# %%
select(dm, -(carat:price))[1:20,]
# Out:
#    x    y    z
# 1  4.45 4.47 2.77
# 2  8.05 8.01 5.19
# 3  5.23 5.26 3.26
# 4  6.99 6.91 4.26
# 5  4.31 4.34 2.68
# 6  4.37 4.40 2.71
# 7  6.58 6.55 3.92
# 8  4.07 4.10 2.45
# 9  5.08 5.11 3.17
# 10 6.29 6.40 4.04
# 11 6.13 6.12 3.62
# 12 5.97 5.90 3.69
# 13 4.80 4.84 2.86
# 14 4.10 4.08 2.52
# 15 6.30 6.22 3.94
# 16 4.24 4.29 2.68
# 17 5.29 5.33 3.20
# 18 5.19 5.16 3.10
# 19 5.26 5.23 3.23
# 20 7.10 7.14 4.40

# %% [markdown]
# Use rename(), which is a variant of select(), to rename a column and keep all the variables that aren't explicitly mentioned:

# %%
rename(dm, width=x)[1:20,]
# Out:
#    carat cut       color clarity depth table price width y    z
# 1  0.33  Ideal     F     VS2     62.1  55     666  4.45  4.47 2.77
# 2  2.10  Fair      G     I1      64.6  58    6597  8.05  8.01 5.19
# 3  0.54  Ideal     E     VVS2    62.2  54    2616  5.23  5.26 3.26
# 4  1.26  Premium   F     SI2     61.3  58    6657  6.99  6.91 4.26
# 5  0.30  Ideal     D     SI2     62.0  56     426  4.31  4.34 2.68
# 6  0.32  Ideal     D     VVS1    61.8  56     910  4.37  4.40 2.71
# 7  1.02  Premium   D     SI2     59.7  60    5198  6.58  6.55 3.92
# 8  0.24  Very Good E     VVS2    60.0  57     552  4.07  4.10 2.45
# 9  0.51  Ideal     E     VS2     62.2  57    1656  5.08  5.11 3.17
# 10 1.02  Very Good E     SI1     63.7  55    7277  6.29  6.40 4.04
# 11 0.83  Premium   J     SI2     59.1  60    2241  6.13  6.12 3.62
# 12 0.79  Ideal     E     VS2     62.2  55    3861  5.97  5.90 3.69
# 13 0.41  Very Good E     SI1     59.3  61     705  4.80  4.84 2.86
# 14 0.26  Ideal     F     VVS2    61.6  57     769  4.10  4.08 2.52
# 15 0.96  Premium   J     SI1     62.9  59    3187  6.30  6.22 3.94
# 16 0.30  Very Good I     VVS1    62.8  59     552  4.24  4.29 2.68
# 17 0.54  Ideal     H     IF      60.3  55    2210  5.29  5.33 3.20
# 18 0.50  Ideal     F     SI1     59.9  57    1286  5.19  5.16 3.10
# 19 0.53  Ideal     F     VS2     61.6  56    2290  5.26  5.23 3.23
# 20 1.35  Ideal     J     VS2     61.8  54    6754  7.10  7.14 4.40

# %%
select(dm, width = x)[1:20,]
# Out:
#    width
# 1  4.45
# 2  8.05
# 3  5.23
# 4  6.99
# 5  4.31
# 6  4.37
# 7  6.58
# 8  4.07
# 9  5.08
# 10 6.29
# 11 6.13
# 12 5.97
# 13 4.80
# 14 4.10
# 15 6.30
# 16 4.24
# 17 5.29
# 18 5.19
# 19 5.26
# 20 7.10

# %% [markdown]
# Another option is to use select() in conjunction with the everything() helper. This is useful if you have a handful of variables you would like to move to the start of the dtaframe

# %%
select(dm, price, carat, everything())[1:20,]
# Out:
#    price carat cut       color clarity depth table x    y    z
# 1   666  0.33  Ideal     F     VS2     62.1  55    4.45 4.47 2.77
# 2  6597  2.10  Fair      G     I1      64.6  58    8.05 8.01 5.19
# 3  2616  0.54  Ideal     E     VVS2    62.2  54    5.23 5.26 3.26
# 4  6657  1.26  Premium   F     SI2     61.3  58    6.99 6.91 4.26
# 5   426  0.30  Ideal     D     SI2     62.0  56    4.31 4.34 2.68
# 6   910  0.32  Ideal     D     VVS1    61.8  56    4.37 4.40 2.71
# 7  5198  1.02  Premium   D     SI2     59.7  60    6.58 6.55 3.92
# 8   552  0.24  Very Good E     VVS2    60.0  57    4.07 4.10 2.45
# 9  1656  0.51  Ideal     E     VS2     62.2  57    5.08 5.11 3.17
# 10 7277  1.02  Very Good E     SI1     63.7  55    6.29 6.40 4.04
# 11 2241  0.83  Premium   J     SI2     59.1  60    6.13 6.12 3.62
# 12 3861  0.79  Ideal     E     VS2     62.2  55    5.97 5.90 3.69
# 13  705  0.41  Very Good E     SI1     59.3  61    4.80 4.84 2.86
# 14  769  0.26  Ideal     F     VVS2    61.6  57    4.10 4.08 2.52
# 15 3187  0.96  Premium   J     SI1     62.9  59    6.30 6.22 3.94
# 16  552  0.30  Very Good I     VVS1    62.8  59    4.24 4.29 2.68
# 17 2210  0.54  Ideal     H     IF      60.3  55    5.29 5.33 3.20
# 18 1286  0.50  Ideal     F     SI1     59.9  57    5.19 5.16 3.10
# 19 2290  0.53  Ideal     F     VS2     61.6  56    5.26 5.23 3.23
# 20 6754  1.35  Ideal     J     VS2     61.8  54    7.10 7.14 4.40

# %% [markdown]
# There are some helper functions for select():
#     starts_with()
#     ends_with()
#     contains()
#
# ### Exercise:
# 1. Write code that wil have price as the first column and the columns starting with the letter 'c' as the following columns. Output the first 20 rows of such a datset.
#
# ### Mutate
# to create a computed column

# %%
dm_dimensions = select(dm, 
  -(carat:price)
)
mutate(dm_dimensions,
  volume = x*y*z
)[1:20,]
# Out:
#    x    y    z    volume
# 1  4.45 4.47 2.77  55.09945
# 2  8.05 8.01 5.19 334.65380
# 3  5.23 5.26 3.26  89.68195
# 4  6.99 6.91 4.26 205.76183
# 5  4.31 4.34 2.68  50.13047
# 6  4.37 4.40 2.71  52.10788
# 7  6.58 6.55 3.92 168.94808
# 8  4.07 4.10 2.45  40.88315
# 9  5.08 5.11 3.17  82.28940
# 10 6.29 6.40 4.04 162.63424
# 11 6.13 6.12 3.62 135.80647
# 12 5.97 5.90 3.69 129.97287
# 13 4.80 4.84 2.86  66.44352
# 14 4.10 4.08 2.52  42.15456
# 15 6.30 6.22 3.94 154.39284
# 16 4.24 4.29 2.68  48.74813
# 17 5.29 5.33 3.20  90.22624
# 18 5.19 5.16 3.10  83.01924
# 19 5.26 5.23 3.23  88.85665
# 20 7.10 7.14 4.40 223.05360

# %% [markdown]
# If you only want to keep the new variables, use transmute()

# %%
transmute(dm_dimensions, 
          volume = x*y*z)[1:20,]
# Out:
#    volume
# 1   55.09945
# 2  334.65380
# 3   89.68195
# 4  205.76183
# 5   50.13047
# 6   52.10788
# 7  168.94808
# 8   40.88315
# 9   82.28940
# 10 162.63424
# 11 135.80647
# 12 129.97287
# 13  66.44352
# 14  42.15456
# 15 154.39284
# 16  48.74813
# 17  90.22624
# 18  83.01924
# 19  88.85665
# 20 223.05360

# %% [markdown]
# Read Section 5.5.1 in the book for some specific functions.
#
# ### Exercise
# 1. Add a new column that converts the US dollar prices to Korean Won amounts and rounds to the nearest integer. Then order the columns as [carat, WON price, price, ...] where '...' stands for everything else. Today's exchange rate is USD = 1070 WON
#
# ## Summarise
# Generally used in concert with group_by() function to output summaries by group. Group summaries are seen in many applications

# %%
by_color = group_by(dm, color)
summarise(by_color, avg_price = mean(price, na.rm = TRUE))
# Out:
#   color avg_price
# 1 D     2727.400
# 2 E     3319.500
# 3 F     3351.632
# 4 G     4097.361
# 5 H     4394.646
# 6 I     4579.943
# 7 J     5561.892

# %%
head(mpg)
# Out:
#   manufacturer model displ year cyl trans      drv cty hwy fl class
# 1 audi         a4    1.8   1999 4   auto(l5)   f   18  29  p  compact
# 2 audi         a4    1.8   1999 4   manual(m5) f   21  29  p  compact
# 3 audi         a4    2.0   2008 4   manual(m6) f   20  31  p  compact
# 4 audi         a4    2.0   2008 4   auto(av)   f   21  30  p  compact
# 5 audi         a4    2.8   1999 6   auto(l5)   f   16  26  p  compact
# 6 audi         a4    2.8   1999 6   manual(m5) f   18  26  p  compact

# %%
mpg2 = mpg
mpg2$year = as.factor(mpg$year) # telling it we're dealing with a category column
mpg2 = mutate(mpg2, manual = (grepl('manual', trans)))
head(mpg2)
# Out:
#   manufacturer model displ year cyl trans      drv cty hwy fl class   manual
# 1 audi         a4    1.8   1999 4   auto(l5)   f   18  29  p  compact FALSE
# 2 audi         a4    1.8   1999 4   manual(m5) f   21  29  p  compact  TRUE
# 3 audi         a4    2.0   2008 4   manual(m6) f   20  31  p  compact  TRUE
# 4 audi         a4    2.0   2008 4   auto(av)   f   21  30  p  compact FALSE
# 5 audi         a4    2.8   1999 6   auto(l5)   f   16  26  p  compact FALSE
# 6 audi         a4    2.8   1999 6   manual(m5) f   18  26  p  compact  TRUE

# %%
by_maker_yr = group_by(mpg2, manufacturer, year)
hwy_summary = summarise(by_maker_yr,
                       count = n(),
                       hwy = mean(hwy, na.rm = TRUE),
                       cty = mean(cty, na.rm = TRUE))
hwy_summary
# Out:
#    manufacturer year count hwy      cty
# 1  audi         1999  9    26.11111 17.11111
# 2  audi         2008  9    26.77778 18.11111
# 3  chevrolet    1999  7    21.57143 15.14286
# 4  chevrolet    2008 12    22.08333 14.91667
# 5  dodge        1999 16    18.43750 13.37500
# 6  dodge        2008 21    17.57143 12.95238
# 7  ford         1999 15    18.60000 13.93333
# 8  ford         2008 10    20.50000 14.10000
# 9  honda        1999  5    31.60000 24.80000
# 10 honda        2008  4    33.75000 24.00000
# 11 hyundai      1999  6    26.66667 18.33333
# 12 hyundai      2008  8    27.00000 18.87500
# 13 jeep         1999  2    18.50000 14.50000
# 14 jeep         2008  6    17.33333 13.16667
# 15 land rover   1999  2    15.00000 11.00000
# 16 land rover   2008  2    18.00000 12.00000
# 17 lincoln      1999  2    16.50000 11.00000
# 18 lincoln      2008  1    18.00000 12.00000
# 19 mercury      1999  2    17.00000 13.50000
# 20 mercury      2008  2    19.00000 13.00000
# 21 nissan       1999  6    23.50000 17.66667
# 22 nissan       2008  7    25.57143 18.42857
# 23 pontiac      1999  3    26.33333 17.00000
# 24 pontiac      2008  2    26.50000 17.00000
# 25 subaru       1999  6    25.50000 19.00000
# 26 subaru       2008  8    25.62500 19.50000
# 27 toyota       1999 20    24.05000 18.15000
# 28 toyota       2008 14    26.14286 19.07143
# 29 volkswagen   1999 16    29.68750 21.25000
# 30 volkswagen   2008 11    28.54545 20.45455

# %%
hwy_summary_ag = filter(hwy_summary, substring(manufacturer,1,1) %in% c('a','b','c','d','e','f','g'))
hwy_summary_ag
# Out:
#   manufacturer year count hwy      cty
# 1 audi         1999  9    26.11111 17.11111
# 2 audi         2008  9    26.77778 18.11111
# 3 chevrolet    1999  7    21.57143 15.14286
# 4 chevrolet    2008 12    22.08333 14.91667
# 5 dodge        1999 16    18.43750 13.37500
# 6 dodge        2008 21    17.57143 12.95238
# 7 ford         1999 15    18.60000 13.93333
# 8 ford         2008 10    20.50000 14.10000

# %%
ggplot(data = hwy_summary_ag, mapping = aes(x = cty, y = hwy)) + 
geom_point(mapping = aes(color = manufacturer, shape = year))
# Out:
# plot without title

# %% [markdown]
# ## Pipes
# The transformations above can be written as:

# %%
hwy_summary_ag2 = mpg2 %>% 
group_by(manufacturer, year) %>%
summarise(
    count = n(),
    hwy = mean(hwy, na.rm = TRUE),
    cty = mean(cty, na.rm = TRUE)) %>%
filter(substring(manufacturer,1,1) %in% c('a','b','c','d','e','f','g'))

# %%
hwy_summary_ag2
# Out:
#   manufacturer year count hwy      cty
# 1 audi         1999  9    26.11111 17.11111
# 2 audi         2008  9    26.77778 18.11111
# 3 chevrolet    1999  7    21.57143 15.14286
# 4 chevrolet    2008 12    22.08333 14.91667
# 5 dodge        1999 16    18.43750 13.37500
# 6 dodge        2008 21    17.57143 12.95238
# 7 ford         1999 15    18.60000 13.93333
# 8 ford         2008 10    20.50000 14.10000
